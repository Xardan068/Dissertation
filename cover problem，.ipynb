# %%
import numpy as np
rnd = np.random
import math
import matplotlib.pyplot as plt
from docplex.mp.model import Model
import tsplib95 
import networkx as nx
import pandas as pd
import warnings
from itertools import combinations
warnings.filterwarnings("ignore", category=Warning)
problem = tsplib95.load('dantzig42.tsp')
G = problem.get_graph()

# %%
problem.get_weight(33,6)
# Out:
# 42

# %%
n = 42
V = range(1,n+1)
A = [(i,j) for i in V for j in V if i!=j]
D_c = 20
# loc = problem.display_data
c={}
for i in range (len(A)):
    c[A[i]] = problem.get_weight(A[i][0],A[i][1])
    
a = {}
for i in range(len(A)):
    if c[A[i]] < D_c:
        a[A[i]] = 1
    else:
        a[A[i]] = 0
for i in V:
    a[i,i] = 1


#%% Model
mdl = Model("TSP")

# Decision variables
keys_x = [(i,j) for (i,j) in A]
keys_u = [(i,j) for i in V for j in V if  a[i,j]==1]
#define a new v as u[i]
keys_v = [i for i in V]
x = mdl.binary_var_dict(keys_x, name = 'x')
u = mdl.binary_var_dict(keys_u, name = 'u')
v = mdl.continuous_var_dict(keys_v, lb = 0, name = 'v')
#parameter a

mdl.parameters.timelimit=60


# Objective function
mdl.minimize(mdl.sum(x[i,j]*c[i,j]for (i,j) in A) +mdl.sum(0.5*c[i,j]*u[i,j]  for (i,j) in A if a[i,j]==1))


# Constraints
mdl.add_constraints(mdl.sum(x[i,j] for j in V if i!=j) == u[i,i] for i in V)
mdl.add_constraints(mdl.sum(x[j,i] for j in V if i!=j) == u[i,i] for i in V)



#City i can cover city j only if the distance is less than or equal to 50 and a[i, j] is 1
mdl.add_constraints(mdl.sum(u[i, j]*a[i,j] for i in V if a[i,j] ==1) == 1 for j in V)
mdl.add_constraints(u[i, i] >= u[i,j] for i in V for j in V if  a[i,j]==1)

#cover all cities?
# mdl.add_constraints(mdl.sum(u[j,i] for j in V if i != j) >= 1 for i in V)

#if covers another must cover itself

u[0,0] = 0

mdl.add_constraints(v[i]-v[j] + n*x[i,j] <= n-1 for i in range(2,n+1) for j in range(2,n+1) if i!=j)





# Solve and print output
solution = mdl.solve(log_output = True)
print(solution)
# Out:
# Version identifier: 22.1.1.0 | 2022-11-27 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPXPARAM_TimeLimit                               60
# Tried aggregator 2 times.
# MIP Presolve eliminated 53 rows and 8 columns.
# MIP Presolve modified 6 coefficients.
# Aggregator did 10 substitutions.
# Reduced MIP has 1837 rows, 1880 columns, and 8723 nonzeros.
# Reduced MIP has 1839 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (7.65 ticks)
# Probing time = 0.02 sec. (3.00 ticks)
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 1837 rows, 1880 columns, and 8723 nonzeros.
# Reduced MIP has 1839 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (5.97 ticks)
# Probing time = 0.02 sec. (2.90 ticks)
# Clique table members: 4672.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 16 threads.
# Root relaxation solution time = 0.00 sec. (3.70 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0      423.1746   112                    423.1746      115
#       0     0      466.9603   104                   Cuts: 132      208
#       0     0      489.4881   101                    Cuts: 61      252
#       0     0      499.1905    95                    Cuts: 45      292
#       0     0      504.5820   116                    Cuts: 14      330
#       0     0      506.2242   106                    Cuts: 33      358
# Detecting symmetries...
#       0     0      515.0556   126                    Cuts: 34      401
#       0     0      524.0556   113                    Cuts: 60      424
#       0     0      528.1591   122                    Cuts: 56      472
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 0 rows and 525 columns.
# Reduced MIP has 1837 rows, 1342 columns, and 7160 nonzeros.
# Reduced MIP has 1301 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (3.79 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 1837 rows, 1342 columns, and 7160 nonzeros.
# Reduced MIP has 1301 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (4.64 ticks)
# Represolve time = 0.05 sec. (44.93 ticks)
# *  4466+    0                          616.5000      553.2857            10.25%
#    4466     0      551.6702   136      616.5000      Cuts: 73    59328   10.25%
#    4466     0      551.9081   155      616.5000     Cuts: 122    59382   10.25%
#    4466     0      551.9081   134      616.5000      Cuts: 58    59428   10.25%
#    4466     0      551.9102   150      616.5000      Cuts: 51    59462   10.25%
# *  4466+    0                          609.5000      553.2857             9.22%
#    4466     0      551.9113   140      609.5000       Cuts: 7    59465    9.22%
#    4466     0      552.0530   120      609.5000      Cuts: 43    59504    9.22%
#    4466     0      552.1944   134      609.5000      Cuts: 55    59566    9.22%
#    4466     0      552.2222   134      609.5000      Cuts: 30    59597    9.22%
#    4466     0      552.2500   136      609.5000      Cuts: 46    59643    9.22%
#    4466     0      552.2500   144      609.5000      Cuts: 26    59689    9.22%
#    4466     2      552.2500   129      609.5000      553.2857    59689    9.22%
# *  4476+    6                          609.0000      553.5000             9.11%
#    4480    11      563.5417    93      609.0000      553.5000    60107    9.11%
#    4822   225      561.0030    64      609.0000      553.5000    64858    9.11%
#    5934  1108    infeasible            609.0000      553.5000    76954    9.11%
#    7588  2434      572.5238    75      609.0000      553.5000    95405    9.11%
# *  8111+   12                          605.0000      553.5000             8.51%
#    9490  3827      578.5833    44      605.0000      556.0000   113836    8.10%
#   11471  5498      593.2692    39      605.0000      560.1902   138287    7.41%
#   21603 14286      588.7929    89      605.0000      563.2500   241783    6.90%
# Elapsed time = 12.42 sec. (9408.31 ticks, tree = 13.30 MB, solutions = 19)
#   30644 22221      568.9762    17      605.0000      563.7500   329855    6.82%
#   36978 28501      575.8211    43      605.0000      564.2421   398220    6.74%
#   45562 36137      573.2083    16      605.0000      564.7937   480350    6.65%
#   51399 41483      583.6786    12      605.0000      565.0238   540829    6.61%
#   57137 46715      572.7517    26      605.0000      565.0238   602150    6.61%
#   64218 52724      590.1667    10      605.0000      565.0238   674047    6.61%
#   71202 57553      579.9895    34      605.0000      565.0238   738926    6.61%
#
# Performing restart 2
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 0 rows and 166 columns.
# Reduced MIP has 1837 rows, 1176 columns, and 6665 nonzeros.
# Reduced MIP has 1135 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (3.40 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 1837 rows, 1176 columns, and 6665 nonzeros.
# Reduced MIP has 1135 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.00 sec. (4.30 ticks)
# Represolve time = 0.09 sec. (51.54 ticks)
#   71431     0      552.5057   161      605.0000      Cuts: 32   772650    6.48%
#   71431     0      552.5057   142      605.0000       Cuts: 2   772654    6.48%
#   71431     0      552.5833   133      605.0000      Cuts: 45   772688    6.48%
#   71431     0      552.7629   158      605.0000      Cuts: 61   772727    6.48%
#   71431     0      552.8962   155      605.0000      Cuts: 36   772766    6.48%
#   71431     0      552.9254   147      605.0000      Cuts: 62   772818    6.48%
#   71431     0      553.3037   149      605.0000      Cuts: 64   772896    6.48%
#   71431     0      553.3259   153      605.0000      Cuts: 54   772925    6.48%
#   71431     0      553.3370   146      605.0000      Cuts: 16   772944    6.48%
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 0 rows and
#
# Clique cuts applied:  27
# Cover cuts applied:  267
# Implied bound cuts applied:  52
# Flow cuts applied:  34
# Mixed integer rounding cuts applied:  163
# Zero-half cuts applied:  66
# Multi commodity flow cuts applied:  3
# Lift and project cuts applied:  62
# Gomory fractional cuts applied:  19
#
# Root node processing (before b&c):
#   Real time             =    1.75 sec. (1184.37 ticks)
# Parallel b&c, 16 threads:
#   Real time             =   58.30 sec. (44896.28 ticks)
#   Sync time (average)   =    7.25 sec.
#   Wait time (average)   =    0.08 sec.
#                           ------------
# Total (root+branch&cut) =   60.05 sec. (46080.65 ticks)
# solution for: TSP
# objective: 605
# status: FEASIBLE_SOLUTION(1)
# x_1_3=1
# x_3_8=1
# x_8_25=1
# x_11_23=1
# x_13_14=1
# x_14_16=1
# x_16_18=1
# x_17_13=1
# x_18_19=1
# x_19_20=1
# x_20_21=1
# x_21_28=1
# x_23_17=1
# x_24_11=1
# x_25_24=1
# x_28_30=1
# x_30_32=1
# x_32_34=1
# x_34_35=1
# x_35_37=1
# x_37_38=1
# x_38_39=1
# x_39_40=1
# x_40_41=1
# x_41_1=1
# u_1_1=1
# u_1_2=1
# u_1_42=1
# u_3_3=1
# u_3_4=1
# u_8_6=1
# u_8_7=1
# u_8_8=1
# u_8_9=1
# u_11_11=1
# u_11_12=1
# u_13_13=1
# u_14_14=1
# u_14_15=1
# u_16_16=1
# u_17_17=1
# u_18_18=1
# u_19_19=1
# u_20_20=1
# u_21_21=1
# u_23_22=1
# u_23_23=1
# u_24_24=1
# u_24_27=1
# u_25_10=1
# u_25_25=1
# u_25_26=1
# u_28_28=1
# u_28_29=1
# u_30_30=1
# u_30_31=1
# u_32_32=1
# u_32_33=1
# u_34_34=1
# u_35_35=1
# u_37_36=1
# u_37_37=1
# u_38_38=1
# u_39_5=1
# u_39_39=1
# u_40_40=1
# u_41_41=1
# v_8=1.000
# v_9=41.000
# v_11=4.000
# v_13=7.000
# v_14=8.000
# v_16=9.000
# v_17=6.000
# v_18=10.000
# v_19=11.000
# v_20=12.000
# v_21=13.000
# v_23=5.000
# v_24=3.000
# v_25=2.000
# v_28=14.000
# v_30=15.000
# v_32=16.000
# v_34=17.000
# v_35=18.000
# v_37=19.000
# v_38=20.000
# v_39=21.000
# v_40=22.000
# v_41=23.000
# [1,
#  3,
#  8,
#  25,
#  24,
#  11,
#  23,
#  17,
#  13,
#  14,
#  16,
#  18,
#  19,
#  20,
#  21,
#  28,
#  30,
#  32,
#  34,
#  35,
#  37,
#  38,
#  39,
#  40,
#  41,
#  1]

# %%
n = 42
V = range(1,n+1)
A = [(i,j) for i in V for j in V if i!=j]
D_c = 20
# loc = problem.display_data
c={}
for i in range (len(A)):
    c[A[i]] = problem.get_weight(A[i][0],A[i][1])
    
a = {}
for i in range(len(A)):
    if c[A[i]] < D_c:
        a[A[i]] = 1
    else:
        a[A[i]] = 0
for i in V:
    a[i,i] = 1

# %%
[1,3,8,25,24,11,23,17,13,14,16,18,19,20,21,28,30,32,34,35,37,38,39,40,41,1]
